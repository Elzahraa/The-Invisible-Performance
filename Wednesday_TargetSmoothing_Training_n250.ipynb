# %% [markdown]
# # Target smoothing using Wednesday Denoiser Algorithm

# %% [markdown]
# Case: Training n=250 run to assess Wednesday target smoothing algorithm using the Wednesday Noisy-ML Simulation Framework
#
# Part of a paper submission: *The Invisible Performance of Regression Models on Noisy Measurements*
#
# Author: Fatma-Elzahraa Eid, Broad Institute of MIT and Harvard

# %%
# [0] Imports 
import os
import numpy as np
import pandas as pd
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # '2' to suppress TensorFlow informational message (oneDNN)
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr
from scipy.stats import shapiro, anderson
import warnings

# %%
# [1] Simulation Class
class NoiseSimulation:
    """
    Class for performing noise simulation on a neural network model.
    Encapsulates all relevant functions for data generation, training, and evaluation.
    """
    def __init__(self, results_folder='results', results_filename='Wednesday_results_temp.csv',
                 n_rounds=100, 
                 features_range=[10,500],
                 example_factor=200,
                 noise_factor_range=[0.01, 2.0], 
                 smoothing_factor=0.5, 
                 smoothing_iterations=10):
        """
        Initialize the NoiseSimulation class with necessary parameters.
        
        :param results_folder: Folder to save results
        :param results_filename: Name of the results CSV file
        :param n_rounds: Number of simulation rounds
        :param noise_factor_range: Range for noise factor
        :param smoothing_factor: Smoothing factor for label smoothing, 0.5 for averaging 
        :param smoothing_iterations: Number of smoothing iterations
        """
        self.results_folder = results_folder
        self.results_filename = results_filename
        self.n_rounds = n_rounds
        self.features_range = features_range
        self.example_factor = example_factor
        self.noise_factor_range = noise_factor_range
       
        self.smoothing_factor = smoothing_factor
        self.smoothing_iterations = smoothing_iterations
        self.results = {
            'n_features': [], 'n_samples': [], 'corr_Ytrue_Ynoisy1': [], 'corr_Ytrue_Ynoisy2': [],
            'corr_Ynoisy1_Ynoisy2': [], 'corr_pred0_Ytrue': [], 'corr_pred_Ytrue': [], 'corr_pred_Ynoisy1': [],
            'corr_pred_Ynoisy2': [],
            'iteration_corr_pred_Ytrue': [], 'iteration_corr_pred_Ynoisy1': [], 'corr_pred_Ytrue_optimal': []
        }

        # Create the results folder if it does not exist
        if not os.path.exists(self.results_folder):
            os.makedirs(self.results_folder)
        self.results_filename_infolder = os.path.join(self.results_folder, self.results_filename)

    @staticmethod
    def generate_features(n_features=10, n_samples=1000):
        """
        Generate features using various statistical distributions.
        
        :param n_samples: Number of samples to generate
        :param n_features: Number of features to generate
        :return: A 2D NumPy array with generated features
        """
        distribution_pool = [
            lambda: np.random.normal(0, 1, n_samples),
            lambda: np.random.uniform(-1, 1, n_samples),
            lambda: np.random.lognormal(0, 1, n_samples),
            lambda: np.random.exponential(1, n_samples),
            lambda: np.random.beta(2, 5, n_samples),
            lambda: np.random.gamma(2, 2, n_samples)
        ]
        features = [np.random.choice(distribution_pool)() for _ in range(n_features)]
        return np.column_stack(features)

    @staticmethod
    def generate_targets(X):
        """
        Generate target values based on transformations of standardized features.
        
        :param X: Standardized feature matrix
        :return: Generated target values
        """
        expressions_pool = [
            lambda x: np.random.uniform(1.0, 2.0, 1)[0] * np.sin(x),
            lambda x: np.log(np.abs(x) + np.random.uniform(0.01, 2.0, 1)[0]),
            lambda x: x ** 2,
            lambda x: x ** 3,
            lambda x: np.sqrt(np.abs(x)),
            lambda x: np.exp(x / (np.abs(x) + np.random.uniform(0.01, 2.0, 1)[0]))
        ]
        terms = [np.random.choice(expressions_pool) for _ in range(X.shape[1])]
        transformed_columns = [term(X[:, i]) for i, term in enumerate(terms)]
        return sum(transformed_columns)

    @staticmethod
    def noise_factor(Y, noise_factor_range=[0.05, 0.1]):
        """
        Determine noise factor based on the standard deviation of target values.
        
        :param Y: Target values
        :param noise_factor_range: Range for noise factor
        :return: Calculated noise level
        """
        variability = np.std(Y)
        noise_factor = np.random.uniform(noise_factor_range[0], noise_factor_range[1])
        noise_level = noise_factor * variability
        return noise_level

    @staticmethod
    def add_noise(Y, noise_level):
        """
        Add Gaussian noise to target values.
        
        :param Y: Target values
        :param noise_level: Standard deviation of the Gaussian noise
        :return: Noisy target values
        """
        return Y + np.random.normal(0, noise_level, Y.shape[0])

    @staticmethod
    def norm_y(Y):
        """
        Normalize target values to ensure normal distribution using log transformation.
        
        :param Y: Target values
        :return: Normalized target values
        """
        warnings.filterwarnings("ignore", message="p-value may not be accurate for N > 5000.")
        _, p_value = shapiro(Y)
        alpha = 0.05
        if p_value < alpha:
            if np.min(Y) <= 0:
                Y = Y - np.min(Y) + 1
            Y_transformed = np.log(Y)
            return Y_transformed
        else:
            return Y

    @staticmethod
    def build_model(input_shape):
        """
        Build and compile a neural network model.
        
        :param input_shape: Shape of the input layer
        :return: Compiled Keras model
        """
        model = keras.Sequential([
            keras.layers.Dense(16, activation='relu', input_shape=input_shape),
            keras.layers.Dense(8, activation='relu'),
            keras.layers.Dense(1)
        ])
        model.compile(optimizer='adam', loss='mse', metrics=['mae'])
        return model

    def run_simulation(self, n_samples=1000, n_features=10, noise_factor_range=[0.01, 2.0]):
        """
        Run a single round of noise simulation.
        
        :param n_samples: Number of samples to generate
        :param n_features: Number of features to generate
        :param noise_factor_range: Range for general noise factor
        :return: Correlation results
        """
        X = self.generate_features(n_features, n_samples)
        X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        X_stacked = np.vstack((X_train_scaled, X_test_scaled))
        Y_stacked = self.generate_targets(X_stacked)
        Y_stacked = self.norm_y(Y_stacked)
        Ytrue_train, Ytrue_test = np.split(Y_stacked, [X_train_scaled.shape[0]], axis=0)
        noise_level1 = self.noise_factor(Ytrue_train, noise_factor_range)
        noise_level2 = self.noise_factor(Ytrue_train, noise_factor_range)
        Y_replicate1 = self.add_noise(Y_stacked, noise_level1)
        Y_replicate2 = self.add_noise(Y_stacked, noise_level2)
        Y_replicate1_train, Y_replicate1_test = np.split(Y_replicate1, [X_train_scaled.shape[0]], axis=0)
        Y_replicate2_train, Y_replicate2_test = np.split(Y_replicate2, [X_train_scaled.shape[0]], axis=0)
        corr_Ytrue_Ynoisy1 = pearsonr(Y_replicate1_train, Ytrue_train)[0]
        corr_Ytrue_Ynoisy2 = pearsonr(Y_replicate2_train, Ytrue_train)[0]
        corr_Ynoisy1_Ynoisy2 = pearsonr(Y_replicate1_train, Y_replicate2_train)[0]

        # Train model on Ytrue and test on Ytrue for optimal performance
        optimal_model = self.build_model((n_features,))
        early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
        optimal_model.fit(X_train_scaled, Ytrue_train, epochs=1000, validation_split=0.2,
                          callbacks=[early_stopping], verbose=0)
        Y_pred_optimal = optimal_model.predict(X_test_scaled).flatten()
        corr_pred_Ytrue_optimal = pearsonr(np.array(Ytrue_test).flatten(), Y_pred_optimal)[0]

        #model1 = self.build_model((n_features,))
        #model2 = self.build_model((n_features,))
        model = self.build_model((n_features,))
        model.fit(X_train_scaled, Y_replicate1_train, epochs=1000, validation_split=0.2,
                  callbacks=[early_stopping], verbose=0)
        Y_pred = model.predict(X_test_scaled).flatten()
        corr_pred0_Ytrue = pearsonr(np.array(Ytrue_test).flatten(), Y_pred)[0]
        
        
        # Wednesday Smoothing
        """
        Input: dataset (X,Ynoisy), where X are features describing an entity, data point, or interactions, Ynoisy is noisy measurements subject to some Gaussian noise. 
        - Let Ystart = Ynoisy
        - Build model on (X,Ystart) 
        - Use the model to predict on X to generate Ypred.
        - Use Equation (Eq1) to assess the true quality of Ystart to see if it needs to be improved
        - If the quality of Ystart needs to be improved (say 0.9), Use Equation (Eq1) 
        to assess whether the quality of Ypred is better than that of Ystart. 
        - If Quality(Ypred)>YQualtiy(Ystart), Ystart= average(Ystart,Ypred)
        - Repeat Steps 3 to 7 until Step 6 condition is not true

        Output: Ystart as the final output and also the starting quality and end quality 

        Eq1: Corr(Ynoisy,Ypred) = sqrt(Cov(Ypred,Ynoisy)/Var(Ypred)) 
        """
        
        iteration_corr_pred_Ytrue = []
        iteration_corr_pred_Ynoisy1 = []
        Y_start = Y_replicate1_train.copy()
        
        for _ in range(self.smoothing_iterations):
            
            # Predict  
            Y_pred = model.predict(X_train_scaled).flatten()
            
            # ---- Convergence Test 
            # Ystart quality 
            A = np.sqrt( np.cov(np.stack((Y_start, Y_pred), axis=0))[0,1])
            B = np.sqrt(np.var(Y_start))
            Y_start_quality =np.divide( A ,  B ) 
            
            # Quality of averaged Ystart,Ypred
            A = np.sqrt( np.cov(np.stack((Y_start, Y_pred), axis=0))[0,1])
            B = np.sqrt(np.var(Y_pred))
            Y_pred_quality =np.divide( A , B ) 
           
            # Test: if new_quality > old_quality, update; else, exist        
            
            
            if   Y_pred_quality >   Y_start_quality:   
                                               
                iteration_corr_pred_Ytrue.append(pearsonr(np.array(Ytrue_train).flatten(), Y_pred)[0])
                iteration_corr_pred_Ynoisy1.append(pearsonr(np.array(Y_replicate1_train).flatten(), Y_pred)[0])
                
                # Update
                Y_start = self.smoothing_factor * Y_start + (1 - self.smoothing_factor) * Y_pred

                # Update                             
                #Y_start = 0.5 * (Y_start + Y_pred)        
                                               
                # New training round 
                model = self.build_model((n_features,))
                model.fit(X_train_scaled, Y_start, epochs=1000, validation_split=0.2,
                          callbacks=[early_stopping], verbose=0)
                                               
                


            else:
                # Update after smoothing 
                Y_pred_test = model.predict(X_test_scaled).flatten()
                
                # Report current iteration qualities 
                corr_pred_Ytrue = pearsonr(np.array(Ytrue_test).flatten(), Y_pred_test)[0]
                corr_pred_Ynoisy1 = pearsonr(np.array(Y_replicate1_test).flatten(), Y_pred_test)[0]
                corr_pred_Ynoisy2 = pearsonr(np.array(Y_replicate2_test).flatten(), Y_pred_test)[0] 
           
                
                break 
            
            # In case Iterations are done but converagence did not happen, to avoid  
            # Report current iteration qualities 
            Y_pred_test = model.predict(X_test_scaled).flatten()
            corr_pred_Ytrue = pearsonr(np.array(Ytrue_test).flatten(), Y_pred_test)[0]
            corr_pred_Ynoisy1 = pearsonr(np.array(Y_replicate1_test).flatten(), Y_pred_test)[0]
            corr_pred_Ynoisy2 = pearsonr(np.array(Y_replicate2_test).flatten(), Y_pred_test)[0] 
       


                                               
        return (corr_Ytrue_Ynoisy1, corr_Ytrue_Ynoisy2, corr_Ynoisy1_Ynoisy2,
                corr_pred0_Ytrue, corr_pred_Ytrue, corr_pred_Ynoisy1, corr_pred_Ynoisy2,
                iteration_corr_pred_Ytrue, iteration_corr_pred_Ynoisy1, corr_pred_Ytrue_optimal)

 
    
    
    def run(self):
        """
        Run the simulation for a specified number of rounds.
        """
        for _ in range(self.n_rounds):
            n_features = np.random.randint(self.features_range[0], self.features_range[1])
            n_samples = n_features * self.example_factor
            (corr_Ytrue_Ynoisy1, corr_Ytrue_Ynoisy2, corr_Ynoisy1_Ynoisy2,
             corr_pred0_Ytrue, corr_pred_Ytrue, corr_pred_Ynoisy1, corr_pred_Ynoisy2,
             iteration_corr_pred_Ytrue, iteration_corr_pred_Ynoisy1, corr_pred_Ytrue_optimal) = self.run_simulation(
                n_samples=n_samples, n_features=n_features,
                noise_factor_range=self.noise_factor_range,
            )
            self.results['n_features'].append(n_features)
            self.results['n_samples'].append(n_samples)
            self.results['corr_Ytrue_Ynoisy1'].append(corr_Ytrue_Ynoisy1)
            self.results['corr_Ytrue_Ynoisy2'].append(corr_Ytrue_Ynoisy2)
            self.results['corr_Ynoisy1_Ynoisy2'].append(corr_Ynoisy1_Ynoisy2)
            self.results['corr_pred0_Ytrue'].append(corr_pred0_Ytrue)
            self.results['corr_pred_Ytrue'].append(corr_pred_Ytrue)
            self.results['corr_pred_Ynoisy1'].append(corr_pred_Ynoisy1)
            self.results['corr_pred_Ynoisy2'].append(corr_pred_Ynoisy2)
            self.results['iteration_corr_pred_Ytrue'].append(iteration_corr_pred_Ytrue)
            self.results['iteration_corr_pred_Ynoisy1'].append(iteration_corr_pred_Ynoisy1)
            self.results['corr_pred_Ytrue_optimal'].append(corr_pred_Ytrue_optimal)

            # Check the lengths of each array in self.results
            lengths = {key: len(value) for key, value in self.results.items()}
            print(lengths)  # Print the lengths to debug

            # Check if all arrays have the same length before creating DataFrame
            array_lengths = [len(arr) for arr in self.results.values()]
            if len(set(array_lengths)) != 1:
                raise ValueError(f"All arrays must be of the same length. Current lengths: {array_lengths}")

            # Save after each iteration, do not wait till the end     
            results_df = pd.DataFrame(self.results)
            results_df.to_csv(self.results_filename_infolder, index=False)

# %%
# [2] Run the Simulation
simulation = NoiseSimulation(results_folder='results', 
                             results_filename='Wednesday_TargetSmoothing_n250.csv',
                             n_rounds=1000, 
                             features_range=[10,100],
                             example_factor=200,
                             noise_factor_range=[0.01, 2.0],
                             smoothing_factor=0.5, 
                             smoothing_iterations=20)
simulation.run()
# Out:
# 112/112 [==============================] - 0s 845us/step
# 112/112 [==============================] - 0s 841us/step
# 445/445 [==============================] - 1s 1ms/step
# 112/112 [==============================] - 0s 868us/step
# 445/445 [==============================] - 0s 926us/step
# 112/112 [==============================] - 0s 836us/step
# 445/445 [==============================] - 1s 1ms/step
# 112/112 [==============================] - 0s 881us/step
# 445/445 [==============================] - 0s 889us/step
# 112/112 [==============================] - 0s 870us/step
# 445/445 [==============================] - 0s 986us/step
# 112/112 [==============================] - 0s 861us/step
# 445/445 [==============================] - 0s 900us/step
# 112/112 [==============================] - 0s 970us/step
# 445/445 [==============================] - 0s 977us/step
# 112/112 [==============================] - 0s 2ms/step
# {'n_features': 1, 'n_samples': 1, 'corr_Ytrue_Ynoisy1': 1, 'corr_Ytrue_Ynoisy2': 1, 'corr_Ynoisy1_Ynoisy2': 1, 'corr_pred0_Ytrue': 1, 'corr_pred_Ytrue': 1, 'corr_pred_Ynoisy1': 1, 'corr_pred_Ynoisy2': 1, 'iteration_corr_pred_Ytrue': 1, 'iteration_corr_pred_Ynoisy1': 1, 'corr_pred_Ytrue_optimal': 1}
# 75/75 [==============================] - 0s 859us/step
# 75/75 [==============================] - 0s 861us/step
# 300/300 [==============================] - 0s 841us/step
# 75/75 [==============================] - 0s 872us/step
# 300/300 [==============================] - 0s 846us/step
# 75/75 [==============================] - 0s 995us/step
# 300/300 [==============================] - 0s 910us/step
# 75/75 [==============================] - 0s 879us/step
# 300/300 [==============================] - 0s 848us/step
# 75/75 [==============================] - 0s 844us/step
# 300/300 [==============================] - 0s 834us/step
# 75/75 [==============================] - 0s 862us/step
# {'n_features': 2, 'n_samples': 2, 'corr_Ytrue_Ynoisy1': 2, 'corr_Ytrue_Ynoisy2': 2, 'corr_Ynoisy1_Ynoisy2': 2, 'corr_pred0_Ytrue': 2, 'corr_pred_Ytrue': 2, 'corr_pred_Ynoisy1': 2, 'corr_pred_Ynoisy2': 2, 'iteration_corr_pred_Ytrue': 2, 'iteration_corr_pred_Ynoisy1': 2, 'corr_pred_Ytrue_optimal': 2}
# 63/63 [==============================] - 0s 875us/step
# 63/63 [==============================] - 0s 862us/step
# 250/250 [==============================] - 0s 896us/step
# 63/63 [==============================] - 0s 889us/step
# 250/250 [==============================] - 0s 910us/step
# 63/63 [==============================] - 0s 864us/step
# 250/250 [==============================] - 0s 910us/step
# 63/63 [==============================] - 0s 859us/step
# 250/250 [==============================] - 0s 933us/step
# 63/63 [==============================] - 0s 860us/step
# 250/250 [==============================] - 0s 931us/step
# 63/63 [==============================] - 0s 863us/step
# {'n_features': 3, 'n_samples': 3, 'corr_Ytrue_Ynoisy1': 3, 'corr_Ytrue_Ynoisy2': 3, 'corr_Ynoisy1_Ynoisy2': 3, 'corr_pred0_Ytrue': 3, 'corr_pred_Ytrue': 3, 'corr_pred_Ynoisy1': 3, 'corr_pred_Ynoisy2': 3, 'iteration_corr_pred_Ytrue': 3, 'iteration_corr_pred_Ynoisy1': 3, 'corr_pred_Ytrue_optimal': 3}
# 78/78 [==============================] - 0s 898us/step
# 78/78 [==============================] - 0s 882us/step
# 310/310 [==============================] - 0s 921us/step
# 78/78 [==============================] - 0s 988us/step
# 310/310 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 851us/step
# 310/310 [==============================] - 0s 891us/step
# 78/78 [==============================] - 0s 927us/step
# 310/310 [==============================] - 0s 923us/step
# 78/78 [==============================] - 0s 844us/step
# 310/310 [==============================] - 0s 897us/step
# 78/78 [==============================] - 0s 897us/step
# 310/310 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 891us/step
# 310/310 [==============================] - 0s 923us/step
# 78/78 [==============================] - 0s 895us/step
# 310/310 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 885us/step
# 310/310 [==============================] - 0s 946us/step
# 78/78 [==============================] - 0s 891us/step
# {'n_features': 4, 'n_samples': 4, 'corr_Ytrue_Ynoisy1': 4, 'corr_Ytrue_Ynoisy2': 4, 'corr_Ynoisy1_Ynoisy2': 4, 'corr_pred0_Ytrue': 4, 'corr_pred_Ytrue': 4, 'corr_pred_Ynoisy1': 4, 'corr_pred_Ynoisy2': 4, 'iteration_corr_pred_Ytrue': 4, 'iteration_corr_pred_Ynoisy1': 4, 'corr_pred_Ytrue_optimal': 4}
# 48/48 [==============================] - 0s 909us/step
# 48/48 [==============================] - 0s 855us/step
# 190/190 [==============================] - 0s 908us/step
# 48/48 [==============================] - 0s 891us/step
# 190/190 [==============================] - 0s 885us/step
# 48/48 [==============================] - 0s 1ms/step
# 190/190 [==============================] - 0s 1ms/step
# 48/48 [==============================] - 0s 873us/step
# 190/190 [==============================] - 0s 889us/step
# 48/48 [==============================] - 0s 946us/step
# 190/190 [==============================] - 0s 1ms/step
# 48/48 [==============================] - 0s 951us/step
# 190/190 [==============================] - 0s 923us/step
# 48/48 [==============================] - 0s 843us/step
# {'n_features': 5, 'n_samples': 5, 'corr_Ytrue_Ynoisy1': 5, 'corr_Ytrue_Ynoisy2': 5, 'corr_Ynoisy1_Ynoisy2': 5, 'corr_pred0_Ytrue': 5, 'corr_pred_Ytrue': 5, 'corr_pred_Ynoisy1': 5, 'corr_pred_Ynoisy2': 5, 'iteration_corr_pred_Ytrue': 5, 'iteration_corr_pred_Ynoisy1': 5, 'corr_pred_Ytrue_optimal': 5}
# 97/97 [==============================] - 0s 846us/step
# 97/97 [==============================] - 0s 851us/step
# 385/385 [==============================] - 1s 2ms/step
# 97/97 [==============================] - 0s 835us/step
# 385/385 [==============================] - 0s 982us/step
# 97/97 [==============================] - 0s 898us/step
# 385/385 [==============================] - 0s 946us/step
# 97/97 [==============================] - 0s 913us/step
# 385/385 [==============================] - 0s 908us/step
# 97/97 [==============================] - 0s 880us/step
# 385/385 [==============================] - 0s 930us/step
# 97/97 [==============================] - 0s 927us/step
# 385/385 [==============================] - 0s 930us/step
# 97/97 [==============================] - 0s 919us/step
# 385/385 [==============================] - 0s 991us/step
# 97/97 [==============================] - 0s 853us/step
# 385/385 [==============================] - 0s 947us/step
# 97/97 [==============================] - 0s 1ms/step
# 385/385 [==============================] - 0s 966us/step
# 97/97 [==============================] - 0s 912us/step
# 385/385 [==============================] - 0s 1ms/step
# 97/97 [==============================] - 0s 885us/step
# {'n_features': 6, 'n_samples': 6, 'corr_Ytrue_Ynoisy1': 6, 'corr_Ytrue_Ynoisy2': 6, 'corr_Ynoisy1_Ynoisy2': 6, 'corr_pred0_Ytrue': 6, 'corr_pred_Ytrue': 6, 'corr_pred_Ynoisy1': 6, 'corr_pred_Ynoisy2': 6, 'iteration_corr_pred_Ytrue': 6, 'iteration_corr_pred_Ynoisy1': 6, 'corr_pred_Ytrue_optimal': 6}
# 60/60 [==============================] - 0s 892us/step
# 60/60 [==============================] - 0s 937us/step
# 240/240 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 838us/step
# 240/240 [==============================] - 0s 809us/step
# 60/60 [==============================] - 0s 912us/step
# 240/240 [==============================] - 0s 867us/step
# 60/60 [==============================] - 0s 885us/step
# 240/240 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 922us/step
# 240/240 [==============================] - 0s 880us/step
# 60/60 [==============================] - 0s 917us/step
# 240/240 [==============================] - 0s 897us/step
# 60/60 [==============================] - 0s 935us/step
# 240/240 [==============================] - 0s 891us/step
# 60/60 [==============================] - 0s 968us/step
# {'n_features': 7, 'n_samples': 7, 'corr_Ytrue_Ynoisy1': 7, 'corr_Ytrue_Ynoisy2': 7, 'corr_Ynoisy1_Ynoisy2': 7, 'corr_pred0_Ytrue': 7, 'corr_pred_Ytrue': 7, 'corr_pred_Ynoisy1': 7, 'corr_pred_Ynoisy2': 7, 'iteration_corr_pred_Ytrue': 7, 'iteration_corr_pred_Ynoisy1': 7, 'corr_pred_Ytrue_optimal': 7}
# 124/124 [==============================] - 0s 862us/step
# 124/124 [==============================] - 0s 906us/step
# 495/495 [==============================] - 0s 955us/step
# 124/124 [==============================] - 0s 896us/step
# 495/495 [==============================] - 0s 947us/step
# 124/124 [==============================] - 0s 851us/step
# 495/495 [==============================] - 0s 928us/step
# 124/124 [==============================] - 0s 954us/step
# 495/495 [==============================] - 0s 947us/step
# 124/124 [==============================] - 0s 872us/step
# 495/495 [==============================] - 0s 944us/step
# 124/124 [==============================] - 0s 2ms/step
# 495/495 [==============================] - 1s 1ms/step
# 124/124 [==============================] - 0s 851us/step
# 495/495 [==============================] - 0s 912us/step
# 124/124 [==============================] - 0s 854us/step
# 495/495 [==============================] - 0s 934us/step
# 124/124 [==============================] - 0s 849us/step
# 495/495 [==============================] - 0s 933us/step
# 124/124 [==============================] - 0s 882us/step
# 495/495 [==============================] - 1s 2ms/step
# 124/124 [==============================] - 0s 837us/step
# 495/495 [==============================] - 0s 911us/step
# 124/124 [==============================] - 0s 836us/step
# {'n_features': 8, 'n_samples': 8, 'corr_Ytrue_Ynoisy1': 8, 'corr_Ytrue_Ynoisy2': 8, 'corr_Ynoisy1_Ynoisy2': 8, 'corr_pred0_Ytrue': 8, 'corr_pred_Ytrue': 8, 'corr_pred_Ynoisy1': 8, 'corr_pred_Ynoisy2': 8, 'iteration_corr_pred_Ytrue': 8, 'iteration_corr_pred_Ynoisy1': 8, 'corr_pred_Ytrue_optimal': 8}
# 109/109 [==============================] - 0s 859us/step
# 109/109 [==============================] - 0s 883us/step
# 435/435 [==============================] - 0s 896us/step
# 109/109 [==============================] - 0s 913us/step
# 435/435 [==============================] - 0s 910us/step
# 109/109 [==============================] - 0s 837us/step
# 435/435 [==============================] - 0s 877us/step
# 109/109 [==============================] - 0s 863us/step
# 435/435 [==============================] - 0s 904us/step
# 109/109 [==============================] - 0s 827us/step
# 435/435 [==============================] - 0s 907us/step
# 109/109 [==============================] - 0s 2ms/step
# 435/435 [==============================] - 0s 931us/step
# 109/109 [==============================] - 0s 874us/step
# 435/435 [==============================] - 0s 918us/step
# 109/109 [==============================] - 0s 862us/step
# 435/435 [==============================] - 0s 916us/step
# 109/109 [==============================] - 0s 841us/step
# {'n_features': 9, 'n_samples': 9, 'corr_Ytrue_Ynoisy1': 9, 'corr_Ytrue_Ynoisy2': 9, 'corr_Ynoisy1_Ynoisy2': 9, 'corr_pred0_Ytrue': 9, 'corr_pred_Ytrue': 9, 'corr_pred_Ynoisy1': 9, 'corr_pred_Ynoisy2': 9, 'iteration_corr_pred_Ytrue': 9, 'iteration_corr_pred_Ynoisy1': 9, 'corr_pred_Ytrue_optimal': 9}
# 89/89 [==============================] - 0s 889us/step
# 89/89 [==============================] - 0s 887us/step
# 355/355 [==============================] - 0s 893us/step
# 89/89 [==============================] - 0s 2ms/step
# 355/355 [==============================] - 0s 1ms/step
# 89/89 [==============================] - 0s 851us/step
# 355/355 [==============================] - 0s 971us/step
# 89/89 [==============================] - 0s 843us/step
# 355/355 [==============================] - 0s 938us/step
# 89/89 [==============================] - 0s 872us/step
# 355/355 [==============================] - 0s 914us/step
# 89/89 [==============================] - 0s 865us/step
# 355/355 [==============================] - 0s 1ms/step
# 89/89 [==============================] - 0s 1ms/step
# 355/355 [==============================] - 1s 1ms/step
# 89/89 [==============================] - 0s 941us/step
# 355/355 [==============================] - 0s 962us/step
# 89/89 [==============================] - 0s 908us/step
# 355/355 [==============================] - 0s 951us/step
# 89/89 [==============================] - 0s 867us/step
# 355/355 [==============================] - 0s 987us/step
# 89/89 [==============================] - 0s 892us/step
# 355/355 [==============================] - 0s 903us/step
# 89/89 [==============================] - 0s 894us/step
# {'n_features': 10, 'n_samples': 10, 'corr_Ytrue_Ynoisy1': 10, 'corr_Ytrue_Ynoisy2': 10, 'corr_Ynoisy1_Ynoisy2': 10, 'corr_pred0_Ytrue': 10, 'corr_pred_Ytrue': 10, 'corr_pred_Ynoisy1': 10, 'corr_pred_Ynoisy2': 10, 'iteration_corr_pred_Ytrue': 10, 'iteration_corr_pred_Ynoisy1': 10, 'corr_pred_Ytrue_optimal': 10}
# 65/65 [==============================] - 0s 877us/step
# 65/65 [==============================] - 0s 915us/step
# 260/260 [==============================] - 0s 846us/step
# 65/65 [==============================] - 0s 888us/step
# 260/260 [==============================] - 0s 883us/step
# 65/65 [==============================] - 0s 953us/step
# 260/260 [==============================] - 0s 860us/step
# 65/65 [==============================] - 0s 861us/step
# {'n_features': 11, 'n_samples': 11, 'corr_Ytrue_Ynoisy1': 11, 'corr_Ytrue_Ynoisy2': 11, 'corr_Ynoisy1_Ynoisy2': 11, 'corr_pred0_Ytrue': 11, 'corr_pred_Ytrue': 11, 'corr_pred_Ynoisy1': 11, 'corr_pred_Ynoisy2': 11, 'iteration_corr_pred_Ytrue': 11, 'iteration_corr_pred_Ynoisy1': 11, 'corr_pred_Ytrue_optimal': 11}
# 73/73 [==============================] - 0s 884us/step
# 73/73 [==============================] - 0s 841us/step
# 290/290 [==============================] - 0s 957us/step
# 73/73 [==============================] - 0s 849us/step
# 290/290 [==============================] - 0s 1ms/step
# 73/73 [==============================] - 0s 943us/step
# 290/290 [==============================] - 0s 958us/step
# 73/73 [==============================] - 0s 913us/step
# 290/290 [==============================] - 0s 933us/step
# 73/73 [==============================] - 0s 873us/step
# 290/290 [==============================] - 0s 897us/step
# 73/73 [==============================] - 0s 850us/step
# 290/290 [==============================] - 0s 950us/step
# 73/73 [==============================] - 0s 901us/step
# 290/290 [==============================] - 0s 939us/step
# 73/73 [==============================] - 0s 912us/step
# 290/290 [==============================] - 0s 1ms/step
# 73/73 [==============================] - 0s 876us/step
# 290/290 [==============================] - 0s 922us/step
# 73/73 [==============================] - 0s 928us/step
# 290/290 [==============================] - 0s 949us/step
# 73/73 [==============================] - 0s 899us/step
# 290/290 [==============================] - 0s 906us/step
# 73/73 [==============================] - 0s 848us/step
# 290/290 [==============================] - 0s 926us/step
# 73/73 [==============================] - 0s 916us/step
# {'n_features': 12, 'n_samples': 12, 'corr_Ytrue_Ynoisy1': 12, 'corr_Ytrue_Ynoisy2': 12, 'corr_Ynoisy1_Ynoisy2': 12, 'corr_pred0_Ytrue': 12, 'corr_pred_Ytrue': 12, 'corr_pred_Ynoisy1': 12, 'corr_pred_Ynoisy2': 12, 'iteration_corr_pred_Ytrue': 12, 'iteration_corr_pred_Ynoisy1': 12, 'corr_pred_Ytrue_optimal': 12}
# 88/88 [==============================] - 0s 896us/step
# 88/88 [==============================] - 0s 851us/step
# 350/350 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 852us/step
# 350/350 [==============================] - 0s 994us/step
# 88/88 [==============================] - 0s 925us/step
# 350/350 [==============================] - 0s 935us/step
# 88/88 [==============================] - 0s 890us/step
# 350/350 [==============================] - 0s 984us/step
# 88/88 [==============================] - 0s 870us/step
# 350/350 [==============================] - 0s 921us/step
# 88/88 [==============================] - 0s 861us/step
# 350/350 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 929us/step
# 350/350 [==============================] - 0s 908us/step
# 88/88 [==============================] - 0s 900us/step
# 350/350 [==============================] - 0s 955us/step
# 88/88 [==============================] - 0s 860us/step
# 350/350 [==============================] - 0s 947us/step
# 88/88 [==============================] - 0s 2ms/step
# {'n_features': 13, 'n_samples': 13, 'corr_Ytrue_Ynoisy1': 13, 'corr_Ytrue_Ynoisy2': 13, 'corr_Ynoisy1_Ynoisy2': 13, 'corr_pred0_Ytrue': 13, 'corr_pred_Ytrue': 13, 'corr_pred_Ynoisy1': 13, 'corr_pred_Ynoisy2': 13, 'iteration_corr_pred_Ytrue': 13, 'iteration_corr_pred_Ynoisy1': 13, 'corr_pred_Ytrue_optimal': 13}
# 109/109 [==============================] - 0s 1ms/step
# 109/109 [==============================] - 0s 877us/step
# 435/435 [==============================] - 0s 921us/step
# 109/109 [==============================] - 0s 840us/step
# 435/435 [==============================] - 0s 910us/step
# 109/109 [==============================] - 0s 864us/step
# 435/435 [==============================] - 0s 916us/step
# 109/109 [==============================] - 0s 883us/step
# 435/435 [==============================] - 0s 904us/step
# 109/109 [==============================] - 0s 864us/step
# 435/435 [==============================] - 0s 1ms/step
# 109/109 [==============================] - 0s 843us/step
# 435/435 [==============================] - 1s 1ms/step
# 109/109 [==============================] - 0s 850us/step
# 435/435 [==============================] - 0s 932us/step
# 109/109 [==============================] - 0s 866us/step
# 435/435 [==============================] - 0s 926us/step
# 109/109 [==============================] - 0s 865us/step
# 435/435 [==============================] - 0s 1ms/step
# 109/109 [==============================] - 0s 825us/step
# 435/435 [==============================] - 0s 938us/step
# 109/109 [==============================] - 0s 855us/step
# 435/435 [==============================] - 1s 1ms/step
# 109/109 [==============================] - 0s 864us/step
# {'n_features': 14, 'n_samples': 14, 'corr_Ytrue_Ynoisy1': 14, 'corr_Ytrue_Ynoisy2': 14, 'corr_Ynoisy1_Ynoisy2': 14, 'corr_pred0_Ytrue': 14, 'corr_pred_Ytrue': 14, 'corr_pred_Ynoisy1': 14, 'corr_pred_Ynoisy2': 14, 'iteration_corr_pred_Ytrue': 14, 'iteration_corr_pred_Ynoisy1': 14, 'corr_pred_Ytrue_optimal': 14}
# 73/73 [==============================] - 0s 870us/step
# 73/73 [==============================] - 0s 883us/step
# 290/290 [==============================] - 0s 992us/step
# 73/73 [==============================] - 0s 864us/step
# 290/290 [==============================] - 0s 1ms/step
# 73/73 [==============================] - 0s 868us/step
# 290/290 [==============================] - 0s 938us/step
# 73/73 [==============================] - 0s 884us/step
# 290/290 [==============================] - 0s 931us/step
# 73/73 [==============================] - 0s 866us/step
# 290/290 [==============================] - 0s 910us/step
# 73/73 [==============================] - 0s 874us/step
# 290/290 [==============================] - 0s 922us/step
# 73/73 [==============================] - 0s 859us/step
# 290/290 [==============================] - 0s 950us/step
# 73/73 [==============================] - 0s 903us/step
# {'n_features': 15, 'n_samples': 15, 'corr_Ytrue_Ynoisy1': 15, 'corr_Ytrue_Ynoisy2': 15, 'corr_Ynoisy1_Ynoisy2': 15, 'corr_pred0_Ytrue': 15, 'corr_pred_Ytrue': 15, 'corr_pred_Ynoisy1': 15, 'corr_pred_Ynoisy2': 15, 'iteration_corr_pred_Ytrue': 15, 'iteration_corr_pred_Ynoisy1': 15, 'corr_pred_Ytrue_optimal': 15}
# 37/37 [==============================] - 0s 921us/step
# 37/37 [==============================] - 0s 846us/step
# 145/145 [==============================] - 0s 947us/step
# 37/37 [==============================] - 0s 922us/step
# 145/145 [==============================] - 0s 951us/step
# 37/37 [==============================] - 0s 897us/step
# 145/145 [==============================] - 0s 927us/step
# 37/37 [==============================] - 0s 935us/step
# 145/145 [==============================] - 0s 903us/step
# 37/37 [==============================] - 0s 882us/step
# 145/145 [==============================] - 0s 943us/step
# 37/37 [==============================] - 0s 931us/step
# 145/145 [==============================] - 0s 953us/step
# 37/37 [==============================] - 0s 899us/step
# 145/145 [==============================] - 0s 961us/step
# 37/37 [==============================] - 0s 914us/step
# 145/145 [==============================] - 0s 925us/step
# 37/37 [==============================] - 0s 895us/step
# 145/145 [==============================] - 0s 915us/step
# 37/37 [==============================] - 0s 902us/step
# 145/145 [==============================] - 0s 940us/step
# 37/37 [==============================] - 0s 891us/step
# 145/145 [==============================] - 0s 923us/step
# 37/37 [==============================] - 0s 901us/step
# 145/145 [==============================] - 0s 1ms/step
# 37/37 [==============================] - 0s 921us/step
# 145/145 [==============================] - 0s 923us/step
# 37/37 [==============================] - 0s 916us/step
# {'n_features': 16, 'n_samples': 16, 'corr_Ytrue_Ynoisy1': 16, 'corr_Ytrue_Ynoisy2': 16, 'corr_Ynoisy1_Ynoisy2': 16, 'corr_pred0_Ytrue': 16, 'corr_pred_Ytrue': 16, 'corr_pred_Ynoisy1': 16, 'corr_pred_Ynoisy2': 16, 'iteration_corr_pred_Ytrue': 16, 'iteration_corr_pred_Ynoisy1': 16, 'corr_pred_Ytrue_optimal': 16}
# 54/54 [==============================] - 0s 883us/step
# 54/54 [==============================] - 0s 872us/step
# 215/215 [==============================] - 0s 928us/step
# 54/54 [==============================] - 0s 875us/step
# 215/215 [==============================] - 0s 961us/step
# 54/54 [==============================] - 0s 897us/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 858us/step
# 215/215 [==============================] - 0s 910us/step
# 54/54 [==============================] - 0s 882us/step
# 215/215 [==============================] - 0s 926us/step
# 54/54 [==============================] - 0s 882us/step
# {'n_features': 17, 'n_samples': 17, 'corr_Ytrue_Ynoisy1': 17, 'corr_Ytrue_Ynoisy2': 17, 'corr_Ynoisy1_Ynoisy2': 17, 'corr_pred0_Ytrue': 17, 'corr_pred_Ytrue': 17, 'corr_pred_Ynoisy1': 17, 'corr_pred_Ynoisy2': 17, 'iteration_corr_pred_Ytrue': 17, 'iteration_corr_pred_Ynoisy1': 17, 'corr_pred_Ytrue_optimal': 17}
# 17/17 [==============================] - 0s 982us/step
# 17/17 [==============================] - 0s 959us/step
# 65/65 [==============================] - 0s 893us/step
# 17/17 [==============================] - 0s 1ms/step
# 65/65 [==============================] - 0s 940us/step
# 17/17 [==============================] - 0s 951us/step
# 65/65 [==============================] - 0s 948us/step
# 17/17 [==============================] - 0s 897us/step
# 65/65 [==============================] - 0s 910us/step
# 17/17 [==============================] - 0s 989us/step
# 65/65 [==============================] - 0s 981us/step
# 17/17 [==============================] - 0s 996us/step
# 65/65 [==============================] - 0s 949us/step
# 17/17 [==============================] - 0s 952us/step
# 65/65 [==============================] - 0s 926us/step
# 17/17 [==============================] - 0s 937us/step
# {'n_features': 18, 'n_samples': 18, 'corr_Ytrue_Ynoisy1': 18, 'corr_Ytrue_Ynoisy2': 18, 'corr_Ynoisy1_Ynoisy2': 18, 'corr_pred0_Ytrue': 18, 'corr_pred_Ytrue': 18, 'corr_pred_Ynoisy1': 18, 'corr_pred_Ynoisy2': 18, 'iteration_corr_pred_Ytrue': 18, 'iteration_corr_pred_Ynoisy1': 18, 'corr_pred_Ytrue_optimal': 18}
# 110/110 [==============================] - 0s 825us/step
# 110/110 [==============================] - 0s 870us/step
# 440/440 [==============================] - 0s 860us/step
# 110/110 [==============================] - 0s 859us/step
# 440/440 [==============================] - 0s 854us/step
# 110/110 [==============================] - 0s 2ms/step
# 440/440 [==============================] - 0s 836us/step
# 110/110 [==============================] - 0s 866us/step
# 440/440 [==============================] - 0s 860us/step
# 110/110 [==============================] - 0s 849us/step
# 440/440 [==============================] - 0s 1ms/step
# 110/110 [==============================] - 0s 851us/step
# 440/440 [==============================] - 0s 844us/step
# 110/110 [==============================] - 0s 831us/step
# 440/440 [==============================] - 0s 870us/step
# 110/110 [==============================] - 0s 901us/step
# 440/440 [==============================] - 0s 859us/step
# 110/110 [==============================] - 0s 869us/step
# 440/440 [==============================] - 0s 867us/step
# 110/110 [==============================] - 0s 866us/step
# 440/440 [==============================] - 0s 859us/step
# 110/110 [==============================] - 0s 897us/step
# {'n_features': 19, 'n_samples': 19, 'corr_Ytrue_Ynoisy1': 19, 'corr_Ytrue_Ynoisy2': 19, 'corr_Ynoisy1_Ynoisy2': 19, 'corr_pred0_Ytrue': 19, 'corr_pred_Ytrue': 19, 'corr_pred_Ynoisy1': 19, 'corr_pred_Ynoisy2': 19, 'iteration_corr_pred_Ytrue': 19, 'iteration_corr_pred_Ynoisy1': 19, 'corr_pred_Ytrue_optimal': 19}
# 55/55 [==============================] - 0s 887us/step
# 55/55 [==============================] - 0s 893us/step
# 220/220 [==============================] - 0s 878us/step
# 55/55 [==============================] - 0s 890us/step
# 220/220 [==============================] - 0s 877us/step
# 55/55 [==============================] - 0s 892us/step
# 220/220 [==============================] - 0s 862us/step
# 55/55 [==============================] - 0s 890us/step
# 220/220 [==============================] - 0s 888us/step
# 55/55 [==============================] - 0s 884us/step
# 220/220 [==============================] - 0s 875us/step
# 55/55 [==============================] - 0s 900us/step
# 220/220 [==============================] - 0s 864us/step
# 55/55 [==============================] - 0s 899us/step
# 220/220 [==============================] - 0s 872us/step
# 55/55 [==============================] - 0s 874us/step
# {'n_features': 20, 'n_samples': 20, 'corr_Ytrue_Ynoisy1': 20, 'corr_Ytrue_Ynoisy2': 20, 'corr_Ynoisy1_Ynoisy2': 20, 'corr_pred0_Ytrue': 20, 'corr_pred_Ytrue': 20, 'corr_pred_Ynoisy1': 20, 'corr_pred_Ynoisy2': 20, 'iteration_corr_pred_Ytrue': 20, 'iteration_corr_pred_Ynoisy1': 20, 'corr_pred_Ytrue_optimal': 20}
# 48/48 [==============================] - 0s 866us/step
# 48/48 [==============================] - 0s 895us/step
# 190/190 [==============================] - 0s 943us/step
# 48/48 [==============================] - 0s 900us/step
# 190/190 [==============================] - 0s 959us/step
# 48/48 [==============================] - 0s 912us/step
# 190/190 [==============================] - 0s 930us/step
# 48/48 [==============================] - 0s 901us/step
# 190/190 [==============================] - 0s 956us/step
# 48/48 [==============================] - 0s 871us/step
# 190/190 [==============================] - 0s 953us/step
# 48/48 [==============================] - 0s 832us/step
# 190/190 [==============================] - 0s 952us/step
# 48/48 [==============================] - 0s 937us/step
# 190/190 [==============================] - 0s 952us/step
# 48/48 [==============================] - 0s 924us/step
# 190/190 [==============================] - 0s 950us/step
# 48/48 [==============================] - 0s 892us/step
# 190/190 [==============================] - 0s 966us/step
# 48/48 [==============================] - 0s 3ms/step
# 190/190 [==============================] - 0s 945us/step
# 48/48 [==============================] - 0s 924us/step
# 190/190 [==============================] - 0s 962us/step
# 48/48 [==============================] - 0s 893us/step
# 190/190 [==============================] - 0s 939us/step
# 48/48 [==============================] - 0s 881us/step
# 190/190 [==============================] - 0s 958us/step
# 48/48 [==============================] - 0s 914us/step
# 190/190 [==============================] - 0s 1ms/step
# 48/48 [==============================] - 0s 907us/step
# 190/190 [==============================] - 0s 924us/step
# 48/48 [==============================] - 0s 876us/step
# {'n_features': 21, 'n_samples': 21, 'corr_Ytrue_Ynoisy1': 21, 'corr_Ytrue_Ynoisy2': 21, 'corr_Ynoisy1_Ynoisy2': 21, 'corr_pred0_Ytrue': 21, 'corr_pred_Ytrue': 21, 'corr_pred_Ynoisy1': 21, 'corr_pred_Ynoisy2': 21, 'iteration_corr_pred_Ytrue': 21, 'iteration_corr_pred_Ynoisy1': 21, 'corr_pred_Ytrue_optimal': 21}
# 70/70 [==============================] - 0s 920us/step
# 70/70 [==============================] - 0s 913us/step
# 280/280 [==============================] - 0s 878us/step
# 70/70 [==============================] - 0s 884us/step
# 280/280 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 874us/step
# 280/280 [==============================] - 0s 876us/step
# 70/70 [==============================] - 0s 857us/step
# 280/280 [==============================] - 0s 864us/step
# 70/70 [==============================] - 0s 908us/step
# 280/280 [==============================] - 0s 890us/step
# 70/70 [==============================] - 0s 898us/step
# 280/280 [==============================] - 0s 884us/step
# 70/70 [==============================] - 0s 914us/step
# 280/280 [==============================] - 0s 876us/step
# 70/70 [==============================] - 0s 885us/step
# {'n_features': 22, 'n_samples': 22, 'corr_Ytrue_Ynoisy1': 22, 'corr_Ytrue_Ynoisy2': 22, 'corr_Ynoisy1_Ynoisy2': 22, 'corr_pred0_Ytrue': 22, 'corr_pred_Ytrue': 22, 'corr_pred_Ynoisy1': 22, 'corr_pred_Ynoisy2': 22, 'iteration_corr_pred_Ytrue': 22, 'iteration_corr_pred_Ynoisy1': 22, 'corr_pred_Ytrue_optimal': 22}
# 20/20 [==============================] - 0s 985us/step
# 20/20 [==============================] - 0s 950us/step
# 80/80 [==============================] - 0s 902us/step
# 20/20 [==============================] - 0s 986us/step
# 80/80 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 971us/step
# 80/80 [==============================] - 0s 898us/step
# 20/20 [==============================] - 0s 935us/step
# 80/80 [==============================] - 0s 859us/step
# 20/20 [==============================] - 0s 972us/step
# 80/80 [==============================] - 0s 909us/step
# 20/20 [==============================] - 0s 976us/step
# 80/80 [==============================] - 0s 900us/step
# 20/20 [==============================] - 0s 1ms/step
# 80/80 [==============================] - 0s 932us/step
# 20/20 [==============================] - 0s 958us/step
# 80/80 [==============================] - 0s 916us/step
# 20/20 [==============================] - 0s 964us/step
# 80/80 [==============================] - 0s 901us/step
# 20/20 [==============================] - 0s 974us/step
# 80/80 [==============================] - 0s 901us/step
# 20/20 [==============================] - 0s 942us/step
# 80/80 [==============================] - 0s 888us/step
# 20/20 [==============================] - 0s 918us/step
# 80/80 [==============================] - 0s 906us/step
# 20/20 [==============================] - 0s 978us/step
# 80/80 [==============================] - 0s 839us/step
# 20/20 [==============================] - 0s 5ms/step
# 80/80 [==============================] - 0s 927us/step
# 20/20 [==============================] - 0s 976us/step
# 80/80 [==============================] - 0s 897us/step
# 20/20 [==============================] - 0s 960us/step
# {'n_features': 23, 'n_samples': 23, 'corr_Ytrue_Ynoisy1': 23, 'corr_Ytrue_Ynoisy2': 23, 'corr_Ynoisy1_Ynoisy2': 23, 'corr_pred0_Ytrue': 23, 'corr_pred_Ytrue': 23, 'corr_pred_Ynoisy1': 23, 'corr_pred_Ynoisy2': 23, 'iteration_corr_pred_Ytrue': 23, 'iteration_corr_pred_Ynoisy1': 23, 'corr_pred_Ytrue_optimal': 23}
# 114/114 [==============================] - 0s 887us/step
# 114/114 [==============================] - 1s 4ms/step
# 455/455 [==============================] - 2s 5ms/step
# 114/114 [==============================] - 1s 3ms/step
# 455/455 [==============================] - 2s 3ms/step
# 114/114 [==============================] - 1s 3ms/step
# 455/455 [==============================] - 2s 4ms/step
# 114/114 [==============================] - 1s 3ms/step
# 455/455 [==============================] - 2s 4ms/step
# 114/114 [==============================] - 1s 4ms/step
# 455/455 [==============================] - 2s 4ms/step
# 114/114 [==============================] - 0s 923us/step
# 455/455 [==============================] - 0s 931us/step
# 114/114 [==============================] - 1s 5ms/step
# 455/455 [==============================] - 2s 4ms/step
# 114/114 [==============================] - 1s 4ms/step
# 455/455 [==============================] - 2s 4ms/step
# 114/114 [==============================] - 0s 844us/step
# 455/455 [==============================] - 0s 949us/step
# 114/114 [==============================] - 1s 4ms/step
# 455/455 [==============================] - 2s 5ms/step
# 114/114 [==============================] - 0s 865us/step
# 455/455 [==============================] - 0s 928us/step
# 114/114 [==============================] - 0s 872us/step
# 455/455 [==============================] - 0s 946us/step
# 114/114 [==============================] - 0s 854us/step
# 455/455 [==============================] - 0s 961us/step
# 114/114 [==============================] - 0s 855us/step
# {'n_features': 24, 'n_samples': 24, 'corr_Ytrue_Ynoisy1': 24, 'corr_Ytrue_Ynoisy2': 24, 'corr_Ynoisy1_Ynoisy2': 24, 'corr_pred0_Ytrue': 24, 'corr_pred_Ytrue': 24, 'corr_pred_Ynoisy1': 24, 'corr_pred_Ynoisy2': 24, 'iteration_corr_pred_Ytrue': 24, 'iteration_corr_pred_Ynoisy1': 24, 'corr_pred_Ytrue_optimal': 24}
# 62/62 [==============================] - 0s 897us/step
# 62/62 [==============================] - 0s 913us/step
# 245/245 [==============================] - 0s 954us/step
# 62/62 [==============================] - 0s 922us/step
# 245/245 [==============================] - 0s 936us/step
# 62/62 [==============================] - 0s 924us/step
# 245/245 [==============================] - 0s 1ms/step
# 62/62 [==============================] - 0s 928us/step
# 245/245 [==============================] - 0s 904us/step
# 62/62 [==============================] - 0s 978us/step
# 245/245 [==============================] - 0s 1ms/step
# 62/62 [==============================] - 0s 940us/step
# 245/245 [==============================] - 0s 968us/step
# 62/62 [==============================] - 0s 931us/step
# 245/245 [==============================] - 0s 1ms/step
# 62/62 [==============================] - 0s 935us/step
# 245/245 [==============================] - 0s 1ms/step
# 62/62 [==============================] - 0s 951us/step
# 245/245 [==============================] - 0s 1ms/step
# 62/62 [==============================] - 0s 1ms/step
# 245/245 [==============================] - 0s 1ms/step
# 62/62 [==============================] - 0s 957us/step
# 245/245 [==============================] - 0s 942us/step
# 62/62 [==============================] - 0s 890us/step
# 245/245 [==============================] - 0s 907us/step
# 62/62 [==============================] - 0s 930us/step
# 245/245 [==============================] - 0s 954us/step
# 62/62 [==============================] - 0s 967us/step
# {'n_features': 25, 'n_samples': 25, 'corr_Ytrue_Ynoisy1': 25, 'corr_Ytrue_Ynoisy2': 25, 'corr_Ynoisy1_Ynoisy2': 25, 'corr_pred0_Ytrue': 25, 'corr_pred_Ytrue': 25, 'corr_pred_Ynoisy1': 25, 'corr_pred_Ynoisy2': 25, 'iteration_corr_pred_Ytrue': 25, 'iteration_corr_pred_Ynoisy1': 25, 'corr_pred_Ytrue_optimal': 25}
# 29/29 [==============================] - 0s 935us/step
# 29/29 [==============================] - 0s 941us/step
# 115/115 [==============================] - 0s 940us/step
# 29/29 [==============================] - 0s 2ms/step
# 115/115 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 963us/step
# 115/115 [==============================] - 0s 891us/step
# 29/29 [==============================] - 0s 968us/step
# 115/115 [==============================] - 0s 981us/step
# 29/29 [==============================] - 0s 930us/step
# 115/115 [==============================] - 0s 956us/step
# 29/29 [==============================] - 0s 997us/step
# 115/115 [==============================] - 0s 918us/step
# 29/29 [==============================] - 0s 936us/step
# 115/115 [==============================] - 0s 949us/step
# 29/29 [==============================] - 0s 931us/step
# {'n_features': 26, 'n_samples': 26, 'corr_Ytrue_Ynoisy1': 26, 'corr_Ytrue_Ynoisy2': 26, 'corr_Ynoisy1_Ynoisy2': 26, 'corr_pred0_Ytrue': 26, 'corr_pred_Ytrue': 26, 'corr_pred_Ynoisy1': 26, 'corr_pred_Ynoisy2': 26, 'iteration_corr_pred_Ytrue': 26, 'iteration_corr_pred_Ynoisy1': 26, 'corr_pred_Ytrue_optimal': 26}
# 94/94 [==============================] - 0s 952us/step
# 94/94 [==============================] - 0s 862us/step
# 375/375 [==============================] - 0s 921us/step
# 94/94 [==============================] - 0s 872us/step
# 375/375 [==============================] - 0s 910us/step
# 94/94 [==============================] - 0s 911us/step
# 375/375 [==============================] - 0s 906us/step
# 94/94 [==============================] - 0s 2ms/step
# 375/375 [==============================] - 0s 923us/step
# 94/94 [==============================] - 0s 883us/step
# 375/375 [==============================] - 0s 929us/step
# 94/94 [==============================] - 0s 2ms/step
# 375/375 [==============================] - 0s 1ms/step
# 94/94 [==============================] - 0s 832us/step
# 375/375 [==============================] - 0s 897us/step
# 94/94 [==============================] - 0s 2ms/step
# 375/375 [==============================] - 0s 916us/step
# 94/94 [==============================] - 0s 848us/step
# 375/375 [==============================] - 0s 893us/step
# 94/94 [==============================] - 0s 2ms/step
# {'n_features': 27, 'n_samples': 27, 'corr_Ytrue_Ynoisy1': 27, 'corr_Ytrue_Ynoisy2': 27, 'corr_Ynoisy1_Ynoisy2': 27, 'corr_pred0_Ytrue': 27, 'corr_pred_Ytrue': 27, 'corr_pred_Ynoisy1': 27, 'corr_pred_Ynoisy2': 27, 'iteration_corr_pred_Ytrue': 27, 'iteration_corr_pred_Ynoisy1': 27, 'corr_pred_Ytrue_optimal': 27}
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 949us/step
# 135/135 [==============================] - 0s 944us/step
# 34/34 [==============================] - 0s 1ms/step
# 135/135 [==============================] - 0s 969us/step
# 34/34 [==============================] - 0s 1ms/step
# 135/135 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 987us/step
# 135/135 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 135/135 [==============================] - 0s 2ms/step
# 34/34 [==============================] - 0s 1ms/step
# {'n_features': 28, 'n_samples': 28, 'corr_Ytrue_Ynoisy1': 28, 'corr_Ytrue_Ynoisy2': 28, 'corr_Ynoisy1_Ynoisy2': 28, 'corr_pred0_Ytrue': 28, 'corr_pred_Ytrue': 28, 'corr_pred_Ynoisy1': 28, 'corr_pred_Ynoisy2': 28, 'iteration_corr_pred_Ytrue': 28, 'iteration_corr_pred_Ynoisy1': 28, 'corr_pred_Ytrue_optimal': 28}
# 43/43 [==============================] - 0s 3ms/step
# 43/43 [==============================] - 0s 1ms/step
# 170/170 [==============================] - 0s 1ms/step
# 43/43 [==============================] - 0s 945us/step
# 170/170 [==============================] - 0s 928us/step
# 43/43 [==============================] - 0s 928us/step
# 170/170 [==============================] - 0s 948us/step
# 43/43 [==============================] - 0s 874us/step
# 170/170 [==============================] - 0s 1ms/step
# 43/43 [==============================] - 0s 876us/step
# 170/170 [==============================] - 0s 887us/step
# 43/43 [==============================] - 0s 935us/step
# 170/170 [==============================] - 0s 938us/step
# 43/43 [==============================] - 0s 935us/step
# 170/170 [==============================] - 0s 2ms/step
# 43/43 [==============================] - 0s 904us/step
# 170/170 [==============================] - 0s 902us/step
# 43/43 [==============================] - 0s 852us/step
# 170/170 [==============================] - 0s 923us/step
# 43/43 [==============================] - 0s 893us/step
# 170/170 [==============================] - 0s 920us/step
# 43/43 [==============================] - 0s 904us/step
# {'n_features': 29, 'n_samples': 29, 'corr_Ytrue_Ynoisy1': 29, 'corr_Ytrue_Ynoisy2': 29, 'corr_Ynoisy1_Ynoisy2': 29, 'corr_pred0_Ytrue': 29, 'corr_pred_Ytrue': 29, 'corr_pred_Ynoisy1': 29, 'corr_pred_Ynoisy2': 29, 'iteration_corr_pred_Ytrue': 29, 'iteration_corr_pred_Ynoisy1': 29, 'corr_pred_Ytrue_optimal': 29}
# 104/104 [==============================] - 0s 858us/step
# 104/104 [==============================] - 0s 847us/step
# 415/415 [==============================] - 0s 1ms/step
# 104/104 [==============================] - 0s 923us/step
# 415/415 [==============================] - 0s 967us/step
# 104/104 [==============================] - 0s 864us/step
# 415/415 [==============================] - 0s 899us/step
# 104/104 [==============================] - 0s 2ms/step
# 415/415 [==============================] - 0s 915us/step
# 104/104 [==============================] - 0s 841us/step
# 415/415 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 860us/step
# 415/415 [==============================] - 0s 935us/step
# 104/104 [==============================] - 0s 909us/step
# 415/415 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 988us/step
# 415/415 [==============================] - 0s 982us/step
# 104/104 [==============================] - 0s 2ms/step
# 415/415 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 940us/step
# 415/415 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 919us/step
# 415/415 [==============================] - 0s 960us/step
# 104/104 [==============================] - 0s 872us/step
# 415/415 [==============================] - 0s 1ms/step
# 104/104 [==============================] - 0s 864us/step
# 415/415 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 898us/step
# 415/415 [==============================] - 0s 963us/step
# 104/104 [==============================] - 0s 826us/step
# {'n_features': 30, 'n_samples': 30, 'corr_Ytrue_Ynoisy1': 30, 'corr_Ytrue_Ynoisy2': 30, 'corr_Ynoisy1_Ynoisy2': 30, 'corr_pred0_Ytrue': 30, 'corr_pred_Ytrue': 30, 'corr_pred_Ynoisy1': 30, 'corr_pred_Ynoisy2': 30, 'iteration_corr_pred_Ytrue': 30, 'iteration_corr_pred_Ynoisy1': 30, 'corr_pred_Ytrue_optimal': 30}
# 112/112 [==============================] - 0s 898us/step
# 112/112 [==============================] - 0s 2ms/step
# 445/445 [==============================] - 0s 938us/step
# 112/112 [==============================] - 0s 845us/step
# 445/445 [==============================] - 1s 1ms/step
# 112/112 [==============================] - 0s 851us/step
# 445/445 [==============================] - 0s 900us/step
# 112/112 [==============================] - 0s 879us/step
# 445/445 [==============================] - 1s 1ms/step
# 112/112 [==============================] - 0s 892us/step
# 445/445 [==============================] - 1s 1ms/step
# 112/112 [==============================] - 0s 940us/step
# 445/445 [==============================] - 0s 966us/step
# 112/112 [==============================] - 0s 896us/step
# 445/445 [==============================] - 1s 1ms/step
# 112/112 [==============================] - 0s 853us/step
# 445/445 [==============================] - 1s 1ms/step
# 112/112 [==============================] - 0s 916us/step
# 445/445 [==============================] - 0s 942us/step
# 112/112 [==============================] - 0s 853us/step
# {'n_features': 31, 'n_samples': 31, 'corr_Ytrue_Ynoisy1': 31, 'corr_Ytrue_Ynoisy2': 31, 'corr_Ynoisy1_Ynoisy2': 31, 'corr_pred0_Ytrue': 31, 'corr_pred_Ytrue': 31, 'corr_pred_Ynoisy1': 31, 'corr_pred_Ynoisy2': 31, 'iteration_corr_pred_Ytrue': 31, 'iteration_corr_pred_Ynoisy1': 31, 'corr_pred_Ytrue_optimal': 31}
# 17/17 [==============================] - 0s 996us/step
# 17/17 [==============================] - 0s 946us/step
# 65/65 [==============================] - 0s 936us/step
# 17/17 [==============================] - 0s 968us/step
# 65/65 [==============================] - 0s 920us/step
# 17/17 [==============================] - 0s 994us/step
# 65/65 [==============================] - 0s 964us/step
# 17/17 [==============================] - 0s 950us/step
# 65/65 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 1ms/step
# 65/65 [==============================] - 0s 955us/step
# 17/17 [==============================] - 0s 976us/step
# 65/65 [==============================] - 0s 990us/step
# 17/17 [==============================] - 0s 972us/step
# 65/65 [==============================] - 0s 974us/step
# 17/17 [==============================] - 0s 1ms/step
# 65/65 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 951us/step
# 65/65 [==============================] - 0s 980us/step
# 17/17 [==============================] - 0s 987us/step
# 65/65 [==============================] - 0s 920us/step
# 17/17 [==============================] - 0s 1ms/step
# 65/65 [==============================] - 0s 949us/step
# 17/17 [==============================] - 0s 1ms/step
# {'n_features': 32, 'n_samples': 32, 'corr_Ytrue_Ynoisy1': 32, 'corr_Ytrue_Ynoisy2': 32, 'corr_Ynoisy1_Ynoisy2': 32, 'corr_pred0_Ytrue': 32, 'corr_pred_Ytrue': 32, 'corr_pred_Ynoisy1': 32, 'corr_pred_Ynoisy2': 32, 'iteration_corr_pred_Ytrue': 32, 'iteration_corr_pred_Ynoisy1': 32, 'corr_pred_Ytrue_optimal': 32}
# 110/110 [==============================] - 0s 876us/step
# 110/110 [==============================] - 0s 860us/step
# 440/440 [==============================] - 0s 823us/step
# 110/110 [==============================] - 0s 862us/step
# 440/440 [==============================] - 0s 1ms/step
# 110/110 [==============================] - 0s 842us/step
# 440/440 [==============================] - 0s 865us/step
# 110/110 [==============================] - 0s 842us/step
# 440/440 [==============================] - 0s 877us/step
# 110/110 [==============================] - 0s 892us/step
# 440/440 [==============================] - 0s 1ms/step
# 110/110 [==============================] - 0s 878us/step
# 440/440 [==============================] - 0s 871us/step
# 110/110 [==============================] - 0s 2ms/step
# 440/440 [==============================] - 0s 874us/step
# 110/110 [==============================] - 0s 895us/step
# 440/440 [==============================] - 0s 1ms/step
# 110/110 [==============================] - 0s 942us/step
# 440/440 [==============================] - 1s 1ms/step
# 110/110 [==============================] - 0s 882us/step
# 440/440 [==============================] - 0s 880us/step
# 110/110 [==============================] - 0s 871us/step
# 440/440 [==============================] - 1s 1ms/step
# 110/110 [==============================] - 0s 874us/step
# 440/440 [==============================] - 0s 1ms/step
# 110/110 [==============================] - 0s 868us/step
# 440/440 [==============================] - 0s 843us/step
# 110/110 [==============================] - 0s 853us/step
# {'n_features': 33, 'n_samples': 33, 'corr_Ytrue_Ynoisy1': 33, 'corr_Ytrue_Ynoisy2': 33, 'corr_Ynoisy1_Ynoisy2': 33, 'corr_pred0_Ytrue': 33, 'corr_pred_Ytrue': 33, 'corr_pred_Ynoisy1': 33, 'corr_pred_Ynoisy2': 33, 'iteration_corr_pred_Ytrue': 33, 'iteration_corr_pred_Ynoisy1': 33, 'corr_pred_Ytrue_optimal': 33}
# 29/29 [==============================] - 0s 889us/step
# 29/29 [==============================] - 0s 904us/step
# 115/115 [==============================] - 0s 932us/step
# ...
# 119/119 [==============================] - 0s 3ms/step
# 475/475 [==============================] - 1s 3ms/step
# 119/119 [==============================] - 0s 2ms/step
# 475/475 [==============================] - 1s 2ms/step
# 119/119 [==============================] - 0s 3ms/step
# 475/475 [==============================] - 1s 3ms/step
# 119/119 [==============================] - 0s 2ms/step
# 475/475 [==============================] - 1s 2ms/step
# 119/119 [==============================] - 0s 2ms/step
# {'n_features': 242, 'n_samples': 242, 'corr_Ytrue_Ynoisy1': 242, 'corr_Ytrue_Ynoisy2': 242, 'corr_Ynoisy1_Ynoisy2': 242, 'corr_pred0_Ytrue': 242, 'corr_pred_Ytrue': 242, 'corr_pred_Ynoisy1': 242, 'corr_pred_Ynoisy2': 242, 'iteration_corr_pred_Ytrue': 242, 'iteration_corr_pred_Ynoisy1': 242, 'corr_pred_Ytrue_optimal': 242}
# 97/97 [==============================] - 0s 3ms/step
# 97/97 [==============================] - 1s 4ms/step
# 385/385 [==============================] - 1s 3ms/step
# 97/97 [==============================] - 0s 3ms/step
# 385/385 [==============================] - 1s 3ms/step
# 97/97 [==============================] - 0s 3ms/step
# 385/385 [==============================] - 1s 3ms/step
# 97/97 [==============================] - 0s 2ms/step
# 385/385 [==============================] - 1s 3ms/step
# 97/97 [==============================] - 0s 2ms/step
# {'n_features': 243, 'n_samples': 243, 'corr_Ytrue_Ynoisy1': 243, 'corr_Ytrue_Ynoisy2': 243, 'corr_Ynoisy1_Ynoisy2': 243, 'corr_pred0_Ytrue': 243, 'corr_pred_Ytrue': 243, 'corr_pred_Ynoisy1': 243, 'corr_pred_Ynoisy2': 243, 'iteration_corr_pred_Ytrue': 243, 'iteration_corr_pred_Ynoisy1': 243, 'corr_pred_Ytrue_optimal': 243}
# 69/69 [==============================] - 0s 2ms/step
# 69/69 [==============================] - 0s 2ms/step
# 275/275 [==============================] - 1s 2ms/step
# 69/69 [==============================] - 0s 1ms/step
# 275/275 [==============================] - 0s 1ms/step
# 69/69 [==============================] - 0s 2ms/step
# 275/275 [==============================] - 0s 2ms/step
# 69/69 [==============================] - 0s 2ms/step
# 275/275 [==============================] - 0s 2ms/step
# 69/69 [==============================] - 0s 1ms/step
# 275/275 [==============================] - 0s 1ms/step
# 69/69 [==============================] - 0s 1ms/step
# 275/275 [==============================] - 0s 1ms/step
# 69/69 [==============================] - 0s 1ms/step
# 275/275 [==============================] - 0s 1ms/step
# 69/69 [==============================] - 0s 1ms/step
# {'n_features': 244, 'n_samples': 244, 'corr_Ytrue_Ynoisy1': 244, 'corr_Ytrue_Ynoisy2': 244, 'corr_Ynoisy1_Ynoisy2': 244, 'corr_pred0_Ytrue': 244, 'corr_pred_Ytrue': 244, 'corr_pred_Ynoisy1': 244, 'corr_pred_Ynoisy2': 244, 'iteration_corr_pred_Ytrue': 244, 'iteration_corr_pred_Ynoisy1': 244, 'corr_pred_Ytrue_optimal': 244}
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 1s 4ms/step
# 70/70 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 2ms/step
# {'n_features': 245, 'n_samples': 245, 'corr_Ytrue_Ynoisy1': 245, 'corr_Ytrue_Ynoisy2': 245, 'corr_Ynoisy1_Ynoisy2': 245, 'corr_pred0_Ytrue': 245, 'corr_pred_Ytrue': 245, 'corr_pred_Ynoisy1': 245, 'corr_pred_Ynoisy2': 245, 'iteration_corr_pred_Ytrue': 245, 'iteration_corr_pred_Ynoisy1': 245, 'corr_pred_Ytrue_optimal': 245}
# 88/88 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 2ms/step
# 350/350 [==============================] - 1s 2ms/step
# 88/88 [==============================] - 0s 2ms/step
# 350/350 [==============================] - 1s 2ms/step
# 88/88 [==============================] - 0s 1ms/step
# 350/350 [==============================] - 1s 1ms/step
# 88/88 [==============================] - 0s 1ms/step
# 350/350 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 1ms/step
# 350/350 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 1ms/step
# 350/350 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 1ms/step
# 350/350 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 1ms/step
# 350/350 [==============================] - 0s 1ms/step
# 88/88 [==============================] - 0s 1ms/step
# {'n_features': 246, 'n_samples': 246, 'corr_Ytrue_Ynoisy1': 246, 'corr_Ytrue_Ynoisy2': 246, 'corr_Ynoisy1_Ynoisy2': 246, 'corr_pred0_Ytrue': 246, 'corr_pred_Ytrue': 246, 'corr_pred_Ynoisy1': 246, 'corr_pred_Ynoisy2': 246, 'iteration_corr_pred_Ytrue': 246, 'iteration_corr_pred_Ynoisy1': 246, 'corr_pred_Ytrue_optimal': 246}
# 40/40 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 2ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# 160/160 [==============================] - 0s 1ms/step
# 40/40 [==============================] - 0s 1ms/step
# {'n_features': 247, 'n_samples': 247, 'corr_Ytrue_Ynoisy1': 247, 'corr_Ytrue_Ynoisy2': 247, 'corr_Ynoisy1_Ynoisy2': 247, 'corr_pred0_Ytrue': 247, 'corr_pred_Ytrue': 247, 'corr_pred_Ynoisy1': 247, 'corr_pred_Ynoisy2': 247, 'iteration_corr_pred_Ytrue': 247, 'iteration_corr_pred_Ynoisy1': 247, 'corr_pred_Ytrue_optimal': 247}
# 54/54 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 1ms/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 978us/step
# 215/215 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# {'n_features': 248, 'n_samples': 248, 'corr_Ytrue_Ynoisy1': 248, 'corr_Ytrue_Ynoisy2': 248, 'corr_Ynoisy1_Ynoisy2': 248, 'corr_pred0_Ytrue': 248, 'corr_pred_Ytrue': 248, 'corr_pred_Ynoisy1': 248, 'corr_pred_Ynoisy2': 248, 'iteration_corr_pred_Ytrue': 248, 'iteration_corr_pred_Ynoisy1': 248, 'corr_pred_Ytrue_optimal': 248}
# 45/45 [==============================] - 0s 971us/step
# 45/45 [==============================] - 0s 1ms/step
# 180/180 [==============================] - 0s 1ms/step
# 45/45 [==============================] - 0s 1ms/step
# 180/180 [==============================] - 0s 1ms/step
# 45/45 [==============================] - 0s 1ms/step
# 180/180 [==============================] - 0s 1ms/step
# 45/45 [==============================] - 0s 934us/step
# 180/180 [==============================] - 0s 990us/step
# 45/45 [==============================] - 0s 1ms/step
# {'n_features': 249, 'n_samples': 249, 'corr_Ytrue_Ynoisy1': 249, 'corr_Ytrue_Ynoisy2': 249, 'corr_Ynoisy1_Ynoisy2': 249, 'corr_pred0_Ytrue': 249, 'corr_pred_Ytrue': 249, 'corr_pred_Ynoisy1': 249, 'corr_pred_Ynoisy2': 249, 'iteration_corr_pred_Ytrue': 249, 'iteration_corr_pred_Ynoisy1': 249, 'corr_pred_Ytrue_optimal': 249}
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 945us/step
# 105/105 [==============================] - 0s 997us/step
# 27/27 [==============================] - 0s 994us/step
# 105/105 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 994us/step
# 105/105 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 919us/step
# 105/105 [==============================] - 0s 947us/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 105/105 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# {'n_features': 250, 'n_samples': 250, 'corr_Ytrue_Ynoisy1': 250, 'corr_Ytrue_Ynoisy2': 250, 'corr_Ynoisy1_Ynoisy2': 250, 'corr_pred0_Ytrue': 250, 'corr_pred_Ytrue': 250, 'corr_pred_Ynoisy1': 250, 'corr_pred_Ynoisy2': 250, 'iteration_corr_pred_Ytrue': 250, 'iteration_corr_pred_Ynoisy1': 250, 'corr_pred_Ytrue_optimal': 250}
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 942us/step
# 235/235 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 972us/step
# 235/235 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 0s 2ms/step
# 59/59 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 0s 2ms/step
# 59/59 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 0s 2ms/step
# 59/59 [==============================] - 0s 2ms/step
# 235/235 [==============================] - 1s 2ms/step
# 59/59 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 1s 2ms/step
# 59/59 [==============================] - 0s 2ms/step
# {'n_features': 251, 'n_samples': 251, 'corr_Ytrue_Ynoisy1': 251, 'corr_Ytrue_Ynoisy2': 251, 'corr_Ynoisy1_Ynoisy2': 251, 'corr_pred0_Ytrue': 251, 'corr_pred_Ytrue': 251, 'corr_pred_Ynoisy1': 251, 'corr_pred_Ynoisy2': 251, 'iteration_corr_pred_Ytrue': 251, 'iteration_corr_pred_Ynoisy1': 251, 'corr_pred_Ytrue_optimal': 251}
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 993us/step
# 60/60 [==============================] - 0s 935us/step
# 15/15 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 992us/step
# 15/15 [==============================] - 1s 1ms/step
# 60/60 [==============================] - 0s 987us/step
# 15/15 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step
# {'n_features': 252, 'n_samples': 252, 'corr_Ytrue_Ynoisy1': 252, 'corr_Ytrue_Ynoisy2': 252, 'corr_Ynoisy1_Ynoisy2': 252, 'corr_pred0_Ytrue': 252, 'corr_pred_Ytrue': 252, 'corr_pred_Ynoisy1': 252, 'corr_pred_Ynoisy2': 252, 'iteration_corr_pred_Ytrue': 252, 'iteration_corr_pred_Ynoisy1': 252, 'corr_pred_Ytrue_optimal': 252}
# 108/108 [==============================] - 0s 1ms/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 1s 1ms/step
# 108/108 [==============================] - 0s 960us/step
# 430/430 [==============================] - 0s 999us/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 1s 1ms/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 0s 1ms/step
# 108/108 [==============================] - 0s 996us/step
# 430/430 [==============================] - 0s 1ms/step
# 108/108 [==============================] - 0s 897us/step
# 430/430 [==============================] - 0s 948us/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 0s 1ms/step
# 108/108 [==============================] - 0s 925us/step
# 430/430 [==============================] - 0s 1ms/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 0s 1ms/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 1s 1ms/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 1s 1ms/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 1s 1ms/step
# 108/108 [==============================] - 0s 879us/step
# 430/430 [==============================] - 1s 1ms/step
# 108/108 [==============================] - 0s 863us/step
# 430/430 [==============================] - 0s 960us/step
# 108/108 [==============================] - 0s 1ms/step
# 430/430 [==============================] - 1s 2ms/step
# KeyboardInterrupt
